# %%
import numpy as np
import scipy as sc
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerTuple

from uncertainties import unumpy as unp
from uncertainties import ufloat, umath

from options import *
from constants import *

nom_vals = unp.nominal_values
std_devs = unp.std_devs

mpl.rcParams.update(rcParams)

# %% [markdown]
# ## 45 degrees (test1)

# %%
#Paramètres utilisés pour la mesure (par défaut)
sampleRate = 2.048e6
centerFreq = 1420e6
centerFreqGHz = centerFreq / 1e9
nfft = 1024

#Lire les données RAW
Raw_data = np.fromfile("../data/test1_2025_02_21_10_20_51_raw.dat", np.complex64)

plt.psd(Raw_data, Fs=sampleRate, Fc=centerFreq, NFFT=nfft, scale_by_freq=False)

plt.show()

# %%
plt.scatter(Raw_data.real[:10000000], Raw_data.imag[:10000000])
plt.xlabel("Real")
plt.ylabel("Imag")
# Out:
# Text(0, 0.5, 'Imag')

# %%
Raw_data
# Out:
# array([-1.       +0.9765625j, -1.       +0.9765625j,
#        -1.       +0.9765625j, ..., -0.015625 +0.03125j  ,
#        -0.0078125+0.0234375j, -0.0234375+0.03125j  ], dtype=complex64)

# %% [markdown]
# ## Batiment BP

# %%
#Lire les données RAW
Raw_data = np.fromfile("../data/batiment_bp_2025_02_21_10_39_47_raw.dat", np.complex64)

plt.psd(Raw_data, Fs=sampleRate, Fc=centerFreq, NFFT=nfft, scale_by_freq=False)
# plt.xlim(1.41999e9, 1.42001e9)

plt.show()

# %% [markdown]
# ## Sun, first observation

# %%
#Lire les données RAW
Raw_data = np.fromfile("../data/tastethesun_2025_02_21_11_03_00_raw.dat", np.complex64)

# %%
plt.psd(Raw_data, Fs=sampleRate, Fc=centerFreq, NFFT=nfft, scale_by_freq=False)

# plt.xlim(1.41999e9, 1.42001e9)
# plt.ylim(-69.5,-62.5)
plt.show()

# %%
plt.scatter(Raw_data.real[:10000000], Raw_data.imag[:10000000])
plt.xlabel("Real")
plt.ylabel("Imag")
# Out:
# Text(0, 0.5, 'Imag')
